# %%
# To ignore warnings
#import warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sweetviz as sv
#from sklearn.model_selection import train_test_split
#from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
#from sklearn.preprocessing import StandardScaler
#from sklearn.linear_model import LinearRegression, Ridge, Lasso
#from sklearn.model_selection import GridSearchCV
#from sklearn import metrics

# %matplotlib inline

# %%
df_home_train = pd.read_csv(r"C:\Users\Eknjz\Desktop\DATA SCIENCE AND MACHINE LEARNING\PROJECT 4\train.csv")
df_home_test=pd.read_csv(r"C:\Users\Eknjz\Desktop\DATA SCIENCE AND MACHINE LEARNING\PROJECT 4\test.csv")

# %%
df_home_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_home_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df_home_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df_home_test.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
print( df_home_train.columns.difference(df_home_test.columns)) # the additional columns which in the train dataset only
# Out:
# Index(['SalePrice'], dtype='object')

# %%
df_home_train.shape
# Out:
# (1460, 81)

# %%
df_home_test.shape
# Out:
# (1459, 80)

# %%
df_home_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df_home_train['MSSubClass'].value_counts()
# Out:
# MSSubClass
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: count, dtype: int64

# %%
df_home_train['MSZoning'].value_counts()
# Out:
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64

# %%
df_home_train['LotFrontage'].value_counts()
# Out:
# LotFrontage
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 137.0      1
# 141.0      1
# 38.0       1
# 140.0      1
# 46.0       1
# Name: count, Length: 110, dtype: int64

# %%
df_home_train[df_home_train['LotFrontage'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 16      17          20       RL          NaN    11241   Pave   NaN      IR1
# 24      25          20       RL          NaN     8246   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1429  1430          20       RL          NaN    12546   Pave   NaN      IR1
# 1431  1432         120       RL          NaN     4928   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
#
# ...

# %%
mean_lot=df_home_train['LotFrontage'].mean()
mean_lot
# Out:
# 70.04995836802665

# %%
df_home_train['LotFrontage'].fillna(mean_lot ,inplace=True)

# %%
df_home_train['LotFrontage'][7]
# Out:
# 70.04995836802665

# %%
df_home_train['LotArea'].value_counts()
# Out:
# LotArea
# 7200     25
# 9600     24
# 6000     17
# 9000     14
# 8400     14
#          ..
# 14601     1
# 13682     1
# 4058      1
# 17104     1
# 9717      1
# Name: count, Length: 1073, dtype: int64

# %%
df_home_train['Street'].value_counts() Alley
# Out:
# Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64

# %%
df_home_train['Alley'].value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %%
df_home_train['Alley'].fillna('NA' ,inplace=True)

# %%
df_home_train['Alley'].value_counts()
# Out:
# Alley
# NA      1369
# Grvl      50
# Pave      41
# Name: count, dtype: int64

# %%
df_home_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df_home_train['LotShape'].value_counts()
# Out:
# LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: count, dtype: int64

# %%
df_home_train['LandContour'].value_counts()
# Out:
# LandContour
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: count, dtype: int64

# %%
df_home_train['Utilities'].value_counts()
# Out:
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: count, dtype: int64

# %%
df_home_train['LotConfig'].value_counts()
# Out:
# LotConfig
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: count, dtype: int64

# %%
df_home_train['LandSlope'].value_counts()
# Out:
# LandSlope
# Gtl    1382
# Mod      65
# Sev      13
# Name: count, dtype: int64

# %%
df_home_train['Neighborhood'].value_counts()
# Out:
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: count, dtype: int64

# %%
df_home_train['Condition1'].value_counts()
# Out:
# Condition1
# Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: count, dtype: int64

# %%
df_home_train['Condition2'].value_counts()
# Out:
# Condition2
# Norm      1445
# Feedr        6
# Artery       2
# RRNn         2
# PosN         2
# PosA         1
# RRAn         1
# RRAe         1
# Name: count, dtype: int64

# %%
df_home_train['Condition1'].value_counts()
# Out:
# Condition1
# Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: count, dtype: int64

# %%
df_home_train['HouseStyle'].value_counts()
# Out:
# HouseStyle
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: count, dtype: int64

# %%
df_home_train['BldgType'].value_counts()
# Out:
# BldgType
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: count, dtype: int64

# %%
df_home_train['MasVnrType'].value_counts()
# Out:
# MasVnrType
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: count, dtype: int64

# %%
df_home_train[df_home_train['MasVnrType'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1        2          20       RL         80.0     9600   Pave    NA      Reg
# 3        4          70       RL         60.0     9550   Pave    NA      IR1
# 5        6          50       RL         85.0    14115   Pave    NA      IR1
# 8        9          50       RM         51.0     6120   Pave    NA      Reg
# 9       10         190       RL         50.0     7420   Pave    NA      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave    NA      Reg
# 1457  1458          70       RL         66.0     9042   Pave    NA      Reg
# 1458  1459          20       RL         68.0     9717   Pave    NA      Reg
# 1459  1460          20       RL         75.0     9937   Pave    NA      Reg
#
# ...

# %%
df_home_train['MasVnrType'].value_counts()
# Out:
# MasVnrType
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: count, dtype: int64

# %%
df_home_train['MasVnrType'].fillna('None',inplace=True)

# %%
df_home_train['MasVnrType'].value_counts()
# Out:
# MasVnrType
# None       872
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: count, dtype: int64

# %%
df_home_train[df_home_train['MasVnrArea'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 234    235          60       RL    70.049958     7851   Pave    NA      Reg
# 529    530          20       RL    70.049958    32668   Pave    NA      IR1
# 650    651          60       FV    65.000000     8125   Pave    NA      Reg
# 936    937          20       RL    67.000000    10083   Pave    NA      Reg
# 973    974          20       FV    95.000000    11639   Pave    NA      Reg
# 977    978         120       FV    35.000000     4274   Pave  Pave      IR1
# 1243  1244          20       RL   107.000000    13891   Pave    NA      Reg
# 1278  1279          60       RL    75.000000     9473   Pave    NA      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 234          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 529          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# ...

# %%
df_home_train['MasVnrArea'].fillna(df_home_train['MasVnrArea'].mean(),inplace=True)

# %%
df_home_train[df_home_train['MasVnrArea'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
df_home_train[df_home_train['BsmtQual'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 17      18          90       RL    72.000000    10791   Pave    NA      Reg
# 39      40          90       RL    65.000000     6040   Pave    NA      Reg
# 90      91          20       RL    60.000000     7200   Pave    NA      Reg
# 102    103          90       RL    64.000000     7018   Pave    NA      Reg
# 156    157          20       RL    60.000000     7200   Pave    NA      Reg
# 182    183          20       RL    60.000000     9060   Pave    NA      Reg
# 259    260          20       RM    70.000000    12702   Pave    NA      Reg
# 342    343          90       RL    70.049958     8544   Pave    NA      Reg
# 362    363          85       RL    64.000000     7301   Pave    NA      Reg
# 371    372          50       RL    80.000000    17120   Pave    NA      Reg
# 392    393          20       RL    70.049958     8339   Pave    NA      IR1
# ...

# %%
df_home_train['BsmtQual'].fillna('NA',inplace=True)

# %%
df_home_train[df_home_train['BsmtQual'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
df_home_train[df_home_train['BsmtCond'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 17      18          90       RL    72.000000    10791   Pave    NA      Reg
# 39      40          90       RL    65.000000     6040   Pave    NA      Reg
# 90      91          20       RL    60.000000     7200   Pave    NA      Reg
# 102    103          90       RL    64.000000     7018   Pave    NA      Reg
# 156    157          20       RL    60.000000     7200   Pave    NA      Reg
# 182    183          20       RL    60.000000     9060   Pave    NA      Reg
# 259    260          20       RM    70.000000    12702   Pave    NA      Reg
# 342    343          90       RL    70.049958     8544   Pave    NA      Reg
# 362    363          85       RL    64.000000     7301   Pave    NA      Reg
# 371    372          50       RL    80.000000    17120   Pave    NA      Reg
# 392    393          20       RL    70.049958     8339   Pave    NA      IR1
# ...

# %%
df_home_train['BsmtCond'].fillna('NA',inplace=True)

# %%
df_home_train[df_home_train['BsmtCond'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
df_home_train[df_home_train['BsmtExposure'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 17      18          90       RL    72.000000    10791   Pave    NA      Reg
# 39      40          90       RL    65.000000     6040   Pave    NA      Reg
# 90      91          20       RL    60.000000     7200   Pave    NA      Reg
# 102    103          90       RL    64.000000     7018   Pave    NA      Reg
# 156    157          20       RL    60.000000     7200   Pave    NA      Reg
# 182    183          20       RL    60.000000     9060   Pave    NA      Reg
# 259    260          20       RM    70.000000    12702   Pave    NA      Reg
# 342    343          90       RL    70.049958     8544   Pave    NA      Reg
# 362    363          85       RL    64.000000     7301   Pave    NA      Reg
# 371    372          50       RL    80.000000    17120   Pave    NA      Reg
# 392    393          20       RL    70.049958     8339   Pave    NA      IR1
# ...

# %%
df_home_train['BsmtExposure'].value_counts()
# Out:
# BsmtExposure
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: count, dtype: int64

# %%
df_home_train['BsmtExposure'].fillna('NA',inplace=True)

# %%
df_home_train[df_home_train['BsmtExposure'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
df_home_train[df_home_train['BsmtFinType1'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 17      18          90       RL    72.000000    10791   Pave    NA      Reg
# 39      40          90       RL    65.000000     6040   Pave    NA      Reg
# 90      91          20       RL    60.000000     7200   Pave    NA      Reg
# 102    103          90       RL    64.000000     7018   Pave    NA      Reg
# 156    157          20       RL    60.000000     7200   Pave    NA      Reg
# 182    183          20       RL    60.000000     9060   Pave    NA      Reg
# 259    260          20       RM    70.000000    12702   Pave    NA      Reg
# 342    343          90       RL    70.049958     8544   Pave    NA      Reg
# 362    363          85       RL    64.000000     7301   Pave    NA      Reg
# 371    372          50       RL    80.000000    17120   Pave    NA      Reg
# 392    393          20       RL    70.049958     8339   Pave    NA      IR1
# ...

# %%
df_home_train['BsmtFinType1'].value_counts()
# Out:
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: count, dtype: int64

# %%
df_home_train['BsmtFinType2'].value_counts()
# Out:
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: count, dtype: int64

# %%
df_home_train['BsmtFinType1'].fillna('NA',inplace=True)
df_home_train['BsmtFinType2'].fillna('NA',inplace=True)

# %%
df_home_train['Electrical'].value_counts()
# Out:
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: count, dtype: int64

# %%
df_home_train[df_home_train['Electrical'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1379  1380          80       RL         73.0     9735   Pave    NA      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1379         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1379      5   2008        WD         Normal     167500
#
# [1 rows x 81 columns]

# %%
df_home_train['Electrical'].fillna('Mix',inplace=True)

# %%
df_home_train['Electrical'].value_counts()
# Out:
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         2
# Name: count, dtype: int64

# %%
df_home_train[df_home_train['FireplaceQu'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL    65.000000     8450   Pave    NA      Reg
# 5        6          50       RL    85.000000    14115   Pave    NA      IR1
# 10      11          20       RL    70.000000    11200   Pave    NA      Reg
# 12      13          20       RL    70.049958    12968   Pave    NA      IR2
# 15      16          45       RM    51.000000     6120   Pave    NA      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1452  1453         180       RM    35.000000     3675   Pave    NA      Reg
# 1453  1454          20       RL    90.000000    17217   Pave    NA      Reg
# 1454  1455          20       FV    62.000000     7500   Pave  Pave      Reg
# 1458  1459          20       RL    68.000000     9717   Pave    NA      Reg
# 1459  1460          20       RL    75.000000     9937   Pave    NA      Reg
#
# ...

# %%
df_home_train['FireplaceQu'].value_counts()
# Out:
# FireplaceQu
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: count, dtype: int64

# %%
df_home_train['FireplaceQu'].fillna('NA',inplace=True)

# %%
df_home_train['FireplaceQu'].value_counts()
# Out:
# FireplaceQu
# NA    690
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: count, dtype: int64

# %%
df_home_train[df_home_train['GarageType'].isnull() & df_home_train['GarageYrBlt'].isnull()& df_home_train['GarageFinish'].isnull() & df_home_train['GarageQual'].isnull()& df_home_train['GarageCond'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 39      40          90       RL    65.000000     6040   Pave    NA      Reg
# 48      49         190       RM    33.000000     4456   Pave    NA      Reg
# 78      79          90       RL    72.000000    10778   Pave    NA      Reg
# 88      89          50  C (all)   105.000000     8470   Pave    NA      IR1
# 89      90          20       RL    60.000000     8070   Pave    NA      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1349  1350          70       RM    50.000000     5250   Pave  Pave      Reg
# 1407  1408          20       RL    70.049958     8780   Pave    NA      IR1
# 1449  1450         180       RM    21.000000     1533   Pave    NA      Reg
# 1450  1451          90       RL    60.000000     9000   Pave    NA      Reg
# 1453  1454          20       RL    90.000000    17217   Pave    NA      Reg
#
# ...

# %%
df_home_train[df_home_train['GarageType'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 39      40          90       RL    65.000000     6040   Pave    NA      Reg
# 48      49         190       RM    33.000000     4456   Pave    NA      Reg
# 78      79          90       RL    72.000000    10778   Pave    NA      Reg
# 88      89          50  C (all)   105.000000     8470   Pave    NA      IR1
# 89      90          20       RL    60.000000     8070   Pave    NA      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1349  1350          70       RM    50.000000     5250   Pave  Pave      Reg
# 1407  1408          20       RL    70.049958     8780   Pave    NA      IR1
# 1449  1450         180       RM    21.000000     1533   Pave    NA      Reg
# 1450  1451          90       RL    60.000000     9000   Pave    NA      Reg
# 1453  1454          20       RL    90.000000    17217   Pave    NA      Reg
#
# ...

# %%
df_home_train['GarageType'].fillna('NA',inplace=True)
df_home_train['GarageFinish'].fillna('NA',inplace=True)
df_home_train['GarageQual'].fillna('NA',inplace=True)
df_home_train['GarageCond'].fillna('NA',inplace=True)
df_home_train['GarageYrBlt'].fillna(0,inplace=True)

# %%
df_home_train[df_home_train['GarageType'].isnull() & df_home_train['GarageYrBlt'].isnull()& df_home_train['GarageFinish'].isnull() & df_home_train['GarageQual'].isnull()& df_home_train['GarageCond'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
df_home_train[df_home_train['PoolQC'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave    NA      Reg
# 1        2          20       RL         80.0     9600   Pave    NA      Reg
# 2        3          60       RL         68.0    11250   Pave    NA      IR1
# 3        4          70       RL         60.0     9550   Pave    NA      IR1
# 4        5          60       RL         84.0    14260   Pave    NA      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave    NA      Reg
# 1456  1457          20       RL         85.0    13175   Pave    NA      Reg
# 1457  1458          70       RL         66.0     9042   Pave    NA      Reg
# 1458  1459          20       RL         68.0     9717   Pave    NA      Reg
# 1459  1460          20       RL         75.0     9937   Pave    NA      Reg
#
# ...

# %%
df_home_train['PoolQC'].fillna('NA',inplace=True)

# %%
df_home_train['PoolQC'].value_counts()
# Out:
# PoolQC
# NA    1453
# Gd       3
# Ex       2
# Fa       2
# Name: count, dtype: int64

# %%
df_home_train[df_home_train['Fence'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave    NA      Reg
# 1        2          20       RL         80.0     9600   Pave    NA      Reg
# 2        3          60       RL         68.0    11250   Pave    NA      IR1
# 3        4          70       RL         60.0     9550   Pave    NA      IR1
# 4        5          60       RL         84.0    14260   Pave    NA      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1453  1454          20       RL         90.0    17217   Pave    NA      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave    NA      Reg
# 1458  1459          20       RL         68.0     9717   Pave    NA      Reg
# 1459  1460          20       RL         75.0     9937   Pave    NA      Reg
#
# ...

# %%
df_home_train['Fence'].value_counts()
# Out:
# Fence
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: count, dtype: int64

# %%
df_home_train['Fence'].fillna('NA',inplace=True)

# %%
df_home_train['Fence'].value_counts()
# Out:
# Fence
# NA       1179
# MnPrv     157
# GdPrv      59
# GdWo       54
# MnWw       11
# Name: count, dtype: int64

# %%
df_home_train['MiscFeature'].value_counts()
# Out:
# MiscFeature
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: count, dtype: int64

# %%
df_home_train['MiscFeature'].fillna('NA',inplace=True)

# %%
df_home_train['MiscFeature'].value_counts()
# Out:
# MiscFeature
# NA      1406
# Shed      49
# Gar2       2
# Othr       2
# TenC       1
# Name: count, dtype: int64

# %%
df_home_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df_home_train[df_home_train.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
df_home_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df_home_test.shape
# Out:
# (1459, 80)

# %%
df_home_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
df_home_test['MSZoning'].value_counts()
# Out:
# MSZoning
# RL         1114
# RM          242
# FV           74
# C (all)      15
# RH           10
# Name: count, dtype: int64

# %%
df_home_test['MSZoning'].fillna("C (all)",inplace=True)

# %%
# Out:
# MSZoning
# RL         1114
# RM          242
# FV           74
# C (all)      15
# RH           10
# C             4
# Name: count, dtype: int64

# %%
df_home_test['LotFrontage'].fillna(mean_lot ,inplace=True)

# %%
df_home_test['Alley'].fillna('NA',inplace=True)

# %%
df_home_test['Utilities'].fillna('ELO',inplace=True)

# %%
df_home_test['Exterior1st'].fillna('Other',inplace=True)

# %%
df_home_test['Exterior2nd'].fillna('Other',inplace=True)

# %%
df_home_test['MasVnrType'].fillna('None',inplace=True)

# %%
df_home_test['MasVnrArea'].fillna(0,inplace=True)

# %%
df_home_test['BsmtQual'].fillna('NA',inplace=True)   
df_home_test['BsmtCond'].fillna('NA',inplace=True) 
df_home_test['BsmtExposure'].fillna('NA',inplace=True) 
df_home_test['BsmtFinType1'].fillna('NA',inplace=True) 
df_home_test['BsmtFinType2'].fillna('NA',inplace=True) 
df_home_test['BsmtFinSF1'].fillna(0,inplace=True)

# %%
df_home_test['BsmtFinSF2'].fillna(0,inplace=True)  
df_home_test['BsmtUnfSF'].fillna(0,inplace=True)  
df_home_test['TotalBsmtSF'].fillna(0,inplace=True)  
df_home_test['BsmtFullBath'].fillna(0,inplace=True)
df_home_test['BsmtHalfBath'].fillna(0,inplace=True)

# %%
df_home_test['KitchenQual'].fillna('Po',inplace=True) 
df_home_test['Functional'].fillna('Sal',inplace=True)

# %%
df_home_test['FireplaceQu'].fillna('NA',inplace=True)
df_home_test['GarageType'].fillna('NA',inplace=True)  
df_home_test['GarageFinish'].fillna('NA',inplace=True)  
df_home_test['GarageQual'].fillna('NA',inplace=True)  
df_home_test['GarageCond'].fillna('NA',inplace=True)  
df_home_test['PoolQC'].fillna('NA',inplace=True)  
df_home_test['MiscFeature'].fillna('NA',inplace=True) 
df_home_test['Fence'].fillna('NA',inplace=True) 
df_home_test['SaleType'].fillna('oth',inplace=True)

# %%
df_home_test['GarageYrBlt'].fillna(0,inplace=True)
df_home_test['GarageCars'].fillna(0,inplace=True)
df_home_test['GarageArea'].fillna(0,inplace=True)

# %%
df_home_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   object
#  3   LotFrontage    1459 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          1459 non-null   object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1459 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
report = sv.analyze(df_home_train)
report.show_html('report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
report.show_html('report_home_train.html')
# Out:
# Report report_home_train.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
report1 = sv.analyze(df_home_test)
report1.show_html('report.html')
report.show_html('report_home_test.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# Report report_home_test.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df_home_test[df_home_test.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []
#
# [0 rows x 80 columns]
